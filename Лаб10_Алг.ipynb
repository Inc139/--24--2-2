# %% [markdown]
# <a href="https://colab.research.google.com/github/Inc139/--24--2-2/blob/main/%D0%9B%D0%B0%D0%B110_%D0%90%D0%BB%D0%B3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1

# %%
nums = list(map(int, input().split()))
result = 0
for num in nums:
    result ^= num
print(result)
# Out:
# 2 2 1
# 1

# %% [markdown]
# 2

# %%
n = int(input())

if n <= 0:
    print(False)
else:
    while n % 4 == 0:
        n //= 4
    print(n == 1)
# Out:
# 16
# True
